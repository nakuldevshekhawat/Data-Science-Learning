# %%
firstname ="nakul"

# %%
firstname
# Out:
# 'nakul'

# %%
print(firstname)
# Out:
# nakul

# %%
lastname="shekhawat"

# %%
lastname
# Out:
# 'shekhawat'

# %%
print(lastname)
# Out:
# shekhawat

# %%
age=20

# %%
age
# Out:
# 20

# %%
type(age)
# Out:
# int

# %%
height=6.0

# %%
height
# Out:
# 6.0

# %%
type(height)
# Out:
# float

# %%
is_check=True

# %%
type(is_check)
# Out:
# bool

# %%
int(height)
# Out:
# 6

# %%
height
# Out:
# 6.0

# %%
print("nakul")
# Out:
# nakul

# %%
answer1=input("enter your item ")

if answer1=="fruit":
    answer2=input("enter your fruit name")
    if answer2=="mango":
        print("task completed")
    else :
        print("task not completed")
else :
    print("item is incorrect")
# Out:
# item is incorrect
