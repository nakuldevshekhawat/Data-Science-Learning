# %%
def get_names(*args):

    for i in args:
        print(i)
    print(args)
    print(type(args))

# %%
get_names('nakul','namr','sj','esjk')
# Out:
# nakul
# namr
# sj
# esjk
# ('nakul', 'namr', 'sj', 'esjk')
# <class 'tuple'>

# %%
def add(**kwargs):
    sum=0
    for i in kwargs:
        sum+=kwargs.get(i)
    print(sum)

# %%
def add(*args,**kwargs):
    sum=0
    for i in args:
        sum+=i
    for i in kwargs:
        sum+=kwargs.get(i)
    print(sum)
    print(kwargs)
    print(args)
    print(type(kwargs))
    print(type(args))
add(2,3,4,1,a=4,e=5)
# Out:
# 19
# {'a': 4, 'e': 5}
# (2, 3, 4, 1)
# <class 'dict'>
# <class 'tuple'>

# %%
a=0
b=0
print(a,b)
def add(a=1,b=1):
    c=a+b
    print(a)
    print(b)
    print(c)
add(5,5)
print(a,b)
# Out:
# 0 0
# 5
# 5
# 10
# 0 0
