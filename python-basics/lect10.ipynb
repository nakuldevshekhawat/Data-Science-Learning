# %%
a=["nakul","nak","naman","narendra","ronak","Nakul"]
for name in a:
    if "nak" in name.lower():
        print(name)
# Out:
# nakul
# nak
# ronak
# Nakul

# %% [markdown]
# # File operations

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/dharmendras/Desktop/Nakul_Folder/Krish_naik/pythonbasics'

# %%
os.listdir('/Users/dharmendras/Desktop/Nakul_Folder/Krish_naik/pythonbasics')
# Out:
# ['prob1.ipynb',
#  'new.ipynb',
#  'lec9.ipynb',
#  'lect8.ipynb',
#  'basic.py',
#  '1.python.ipynb',
#  'test.txt',
#  'lect10.ipynb']

# %%
os.path.join(os.getcwd(),'nakul.txt')
# Out:
# '/Users/dharmendras/Desktop/Nakul_Folder/Krish_naik/pythonbasics/nakul.txt'

# %%
cwd= os.getcwd()

file_name="test.txt"
full_path=os.path.normpath(os.path.join(cwd,file_name))
print((full_path))
print(os.path.exists(full_path))
# Out:
# /Users/dharmendras/Desktop/Nakul_Folder/Krish_naik/pythonbasics/test.txt
# True

# %%
f=open(full_path)

# %%
f.read()
# Out:
# ''

# %%
with open('a.txt','w') as f:
    f.write("hello i am Nakul")

# %%
with open('a.txt','r') as f:
    print(f.read())
# Out:
# hello i am Nakul

# %%
id=1
name=input("Enter your name : ")
age=input("Enter your Age : ")
with open("new.txt",'a+') as f:
    a=str(id)+","+name + ","+age+"\n"
    f.write(a)
id += 1
