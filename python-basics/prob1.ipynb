# %%
money=int(input("enter money"))
time=int(input("enter time"))
if money >= 200:
    if time < 7 :
        print("go to theme part")
    else:
        print("go home")
if money < 200 :
    if time > 7:
         print("icecream parlour")
    else:
         print("go to beach")
# Out:
# go to theme part
